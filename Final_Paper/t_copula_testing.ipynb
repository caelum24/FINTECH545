# %%
import numpy as np
from scipy.stats import t, norm
from copulas.multivariate import GaussianMultivariate, StudentMultivariate


# Example: Simulate portfolio returns using t copula
data = ...  # historical returns


# Fit Student t copula
t_copula = StudentMultivariate()
t_copula.fit(data)


# Simulate new joint returns
simulated = t_copula.sample(10000)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 3
#       1 import numpy as np
#       2 from scipy.stats import t, norm
# ----> 3 from copulas.multivariate import GaussianMultivariate, StudentMultivariate
#       6 # Example: Simulate portfolio returns using t copula
#       7 data = ...  # historical returns
#
# ImportError: cannot import name 'StudentMultivariate' from 'copulas.multivariate' (/Users/willneuner/Desktop/FINTECH545/.venv/lib/python3.12/site-packages/copulas/multivariate/__init__.py)

# %%
import copulas

# %%
dir(copulas.multivariate)
# Out:
# ['GaussianMultivariate',
#  'Multivariate',
#  'Tree',
#  'TreeTypes',
#  'VineCopula',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'base',
#  'gaussian',
#  'tree',
#  'vine']
